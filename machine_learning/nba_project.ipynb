# %%
import joblib
import json
import requests
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('../data/nba_data.csv')
df.head()
# Out:
#    Unnamed: 0         player  all_nba  all_star  draft_yr  pk team  \
# 0           0  Deandre Ayton        0         0      2018   1  PHO
# 1           1  Marvin Bagley        0         0      2018   2  SAC
# 2           2    Luka Doncic        0         0      2018   3  ATL
# 3           3  Jaren Jackson        0         0      2018   4  MEM
# 4           4     Trae Young        0         0      2018   5  DAL
#
#           college  yrs  games  minutes_played   pts  trb  ast  fg_percentage  \
# 0         Arizona    1     71            2183  1159  729  125          0.585
# 1            Duke    1     62            1567   923  471   62          0.504
# 2      No college    1     72            2318  1526  563  429          0.427
# 3  Michigan State    1     58            1515   798  272   64          0.506
# 4        Oklahoma    1     81            2503  1549  301  653          0.418
#
#    tp_percentage  ft_percentage  minutes_per_game  points_per_game  \
# 0          0.000          0.746              30.7             16.3
# 1          0.313          0.691              25.3             14.9
# 2          0.327          0.713              32.2             21.2
# 3          0.359          0.766              26.1             13.8
# 4          0.324          0.829              30.9             19.1
#
#    trb_per_game  assists_per_game  win_share  ws_per_game  bpm  vorp  \
# 0          10.3               1.8        5.8        0.128  0.2   1.2
# 1           7.6               1.0        3.6        0.110 -1.8   0.1
# 2           7.8               6.0        4.9        0.101  4.1   3.6
# 3           4.7               1.1        3.3        0.105  0.1   0.8
# 4           3.7               8.1        3.3        0.062 -1.1   0.6
#
#    attend_college
# 0            True
# 1            True
# 2           False
# 3            True
# 4            True

# %%
# First drop: dropping useless columns
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#           player  all_nba  all_star  draft_yr  pk team         college  yrs  \
# 0  Deandre Ayton        0         0      2018   1  PHO         Arizona    1
# 1  Marvin Bagley        0         0      2018   2  SAC            Duke    1
# 2    Luka Doncic        0         0      2018   3  ATL      No college    1
# 3  Jaren Jackson        0         0      2018   4  MEM  Michigan State    1
# 4     Trae Young        0         0      2018   5  DAL        Oklahoma    1
#
#    games  minutes_played   pts  trb  ast  fg_percentage  tp_percentage  \
# 0     71            2183  1159  729  125          0.585          0.000
# 1     62            1567   923  471   62          0.504          0.313
# 2     72            2318  1526  563  429          0.427          0.327
# 3     58            1515   798  272   64          0.506          0.359
# 4     81            2503  1549  301  653          0.418          0.324
#
#    ft_percentage  minutes_per_game  points_per_game  trb_per_game  \
# 0          0.746              30.7             16.3          10.3
# 1          0.691              25.3             14.9           7.6
# 2          0.713              32.2             21.2           7.8
# 3          0.766              26.1             13.8           4.7
# 4          0.829              30.9             19.1           3.7
#
#    assists_per_game  win_share  ws_per_game  bpm  vorp  attend_college
# 0               1.8        5.8        0.128  0.2   1.2            True
# 1               1.0        3.6        0.110 -1.8   0.1            True
# 2               6.0        4.9        0.101  4.1   3.6           False
# 3               1.1        3.3        0.105  0.1   0.8            True
# 4               8.1        3.3        0.062 -1.1   0.6            True

# %%
df.to_csv('nba_data.csv')

# %%
# Second drop: dropping columns with leakage
cols = ['team', 'college', 'games', 'minutes_played', 'pts', 'trb', 'ast', 'win_share']
df = df.drop(columns=cols)
df.head()
# Out:
#           player  all_nba  all_star  draft_yr  pk  yrs  fg_percentage  \
# 0  Deandre Ayton        0         0      2018   1    1          0.585
# 1  Marvin Bagley        0         0      2018   2    1          0.504
# 2    Luka Doncic        0         0      2018   3    1          0.427
# 3  Jaren Jackson        0         0      2018   4    1          0.506
# 4     Trae Young        0         0      2018   5    1          0.418
#
#    tp_percentage  ft_percentage  minutes_per_game  points_per_game  \
# 0          0.000          0.746              30.7             16.3
# 1          0.313          0.691              25.3             14.9
# 2          0.327          0.713              32.2             21.2
# 3          0.359          0.766              26.1             13.8
# 4          0.324          0.829              30.9             19.1
#
#    trb_per_game  assists_per_game  ws_per_game  bpm  vorp  attend_college
# 0          10.3               1.8        0.128  0.2   1.2            True
# 1           7.6               1.0        0.110 -1.8   0.1            True
# 2           7.8               6.0        0.101  4.1   3.6           False
# 3           4.7               1.1        0.105  0.1   0.8            True
# 4           3.7               8.1        0.062 -1.1   0.6            True

# %%
df.describe()
# Out:
#            all_nba     all_star     draft_yr           pk        yrs  \
# count  4165.000000  4165.000000  4165.000000  4165.000000  4165.0000
# mean      0.124130     0.233373  1990.906122    69.540216     3.4000
# std       0.930178     1.270099    12.541098    57.780823     4.6945
# min       0.000000     0.000000  1976.000000     1.000000     0.0000
# 25%       0.000000     0.000000  1981.000000    25.000000     0.0000
# 50%       0.000000     0.000000  1986.000000    49.000000     1.0000
# 75%       0.000000     0.000000  2001.000000   109.000000     6.0000
# max      15.000000    18.000000  2018.000000   228.000000    21.0000
#
#        fg_percentage  tp_percentage  ft_percentage  minutes_per_game  \
# count    4165.000000    4165.000000    4165.000000       4165.000000
# mean        0.238919       0.116188       0.378026          9.626483
# std         0.227010       0.157755       0.365774         10.918073
# min         0.000000       0.000000       0.000000          0.000000
# 25%         0.000000       0.000000       0.000000          0.000000
# 50%         0.340000       0.000000       0.500000          5.700000
# 75%         0.448000       0.280000       0.740000         18.100000
# max         1.000000       1.000000       1.000000         41.100000
#
#        points_per_game  trb_per_game  assists_per_game  ws_per_game  \
# count      4165.000000   4165.000000       4165.000000  4165.000000
# mean          3.847947      1.691597          0.858944     0.031019
# std           5.038110      2.198878          1.368999     0.076914
# min           0.000000      0.000000          0.000000    -1.264000
# 25%           0.000000      0.000000          0.000000     0.000000
# 50%           1.800000      0.900000          0.200000     0.000000
# 75%           6.300000      2.800000          1.200000     0.073000
# max          30.100000     13.700000         11.200000     1.442000
#
#                bpm         vorp
# count  4165.000000  4165.000000
# mean     -1.462257     2.495486
# std       3.396649     9.074733
# min     -53.600000    -8.300000
# 25%      -2.500000    -0.100000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max      19.600000   129.800000

# %%
# show total before cut
df.shape
# Out:
# (4165, 17)

# %%
df = df[df['yrs'] != 0]

# %%
# show shape after cut
df.shape
# Out:
# (2272, 17)

# %%
df.head()
# Out:
#           player  all_nba  all_star  draft_yr  pk  yrs  fg_percentage  \
# 0  Deandre Ayton        0         0      2018   1    1          0.585
# 1  Marvin Bagley        0         0      2018   2    1          0.504
# 2    Luka Doncic        0         0      2018   3    1          0.427
# 3  Jaren Jackson        0         0      2018   4    1          0.506
# 4     Trae Young        0         0      2018   5    1          0.418
#
#    tp_percentage  ft_percentage  minutes_per_game  points_per_game  \
# 0          0.000          0.746              30.7             16.3
# 1          0.313          0.691              25.3             14.9
# 2          0.327          0.713              32.2             21.2
# 3          0.359          0.766              26.1             13.8
# 4          0.324          0.829              30.9             19.1
#
#    trb_per_game  assists_per_game  ws_per_game  bpm  vorp  attend_college
# 0          10.3               1.8        0.128  0.2   1.2            True
# 1           7.6               1.0        0.110 -1.8   0.1            True
# 2           7.8               6.0        0.101  4.1   3.6           False
# 3           4.7               1.1        0.105  0.1   0.8            True
# 4           3.7               8.1        0.062 -1.1   0.6            True

# %%
player = df[['player']]

# %%
# need this for later
player.head()
# Out:
#           player
# 0  Deandre Ayton
# 1  Marvin Bagley
# 2    Luka Doncic
# 3  Jaren Jackson
# 4     Trae Young

# %% [markdown]
# # Split data 3-ways. We will train the model using all players drafted before 1990, validate the model on players drafted between 1990-1999, and test on players drafted in 2000 or later.

# %%
train= df[df['draft_yr'] <1990]
val= df[(df['draft_yr'] >=1990) & (df['draft_yr'] <2000)]
test= df[df['draft_yr'] >=2000]

# %%
train.head()
# Out:
#               player  all_nba  all_star  draft_yr  pk  yrs  fg_percentage  \
# 1688  Pervis Ellison        0         0      1989   1   11          0.510
# 1689     Danny Ferry        0         0      1989   2   13          0.446
# 1690    Sean Elliott        0         2      1989   3   12          0.465
# 1691       Glen Rice        2         3      1989   4   15          0.456
# 1692       J.R. Reid        0         0      1989   5   11          0.472
#
#       tp_percentage  ft_percentage  minutes_per_game  points_per_game  \
# 1688          0.050          0.689              24.5              9.5
# 1689          0.393          0.840              19.8              7.0
# 1690          0.375          0.799              33.0             14.2
# 1691          0.400          0.846              35.0             18.3
# 1692          0.135          0.716              22.9              8.5
#
#       trb_per_game  assists_per_game  ws_per_game  bpm  vorp  attend_college
# 1688           6.7               1.5        0.090  0.5   7.4            True
# 1689           2.8               1.3        0.092 -0.9   5.0            True
# 1690           4.3               2.6        0.109  0.6  16.1            True
# 1691           4.4               2.1        0.122  0.5  22.1            True
# 1692           5.0               1.0        0.070 -2.0  -0.2            True

# %%
val.head()
# Out:
#                player  all_nba  all_star  draft_yr  pk  yrs  fg_percentage  \
# 1129      Elton Brand        1         2      1999   1   17          0.500
# 1130    Steve Francis        0         3      1999   2    9          0.429
# 1131      Baron Davis        1         2      1999   3   13          0.409
# 1132       Lamar Odom        0         0      1999   4   14          0.463
# 1133  Jonathan Bender        0         0      1999   5    8          0.417
#
#       tp_percentage  ft_percentage  minutes_per_game  points_per_game  \
# 1129          0.095          0.736              33.0             15.9
# 1130          0.341          0.797              37.6             18.1
# 1131          0.320          0.711              34.2             16.1
# 1132          0.312          0.693              33.4             13.3
# 1133          0.340          0.763              14.7              5.5
#
#       trb_per_game  assists_per_game  ws_per_game  bpm  vorp  attend_college
# 1129           8.5               2.1        0.151  3.1  45.2            True
# 1130           5.6               6.0        0.120  3.2  28.2            True
# 1131           3.8               7.2        0.106  2.7  34.1            True
# 1132           8.4               3.7        0.115  2.5  36.3            True
# 1133           2.2               0.6        0.047 -3.5  -1.5           False

# %%
test.head()
# Out:
#           player  all_nba  all_star  draft_yr  pk  yrs  fg_percentage  \
# 0  Deandre Ayton        0         0      2018   1    1          0.585
# 1  Marvin Bagley        0         0      2018   2    1          0.504
# 2    Luka Doncic        0         0      2018   3    1          0.427
# 3  Jaren Jackson        0         0      2018   4    1          0.506
# 4     Trae Young        0         0      2018   5    1          0.418
#
#    tp_percentage  ft_percentage  minutes_per_game  points_per_game  \
# 0          0.000          0.746              30.7             16.3
# 1          0.313          0.691              25.3             14.9
# 2          0.327          0.713              32.2             21.2
# 3          0.359          0.766              26.1             13.8
# 4          0.324          0.829              30.9             19.1
#
#    trb_per_game  assists_per_game  ws_per_game  bpm  vorp  attend_college
# 0          10.3               1.8        0.128  0.2   1.2            True
# 1           7.6               1.0        0.110 -1.8   0.1            True
# 2           7.8               6.0        0.101  4.1   3.6           False
# 3           4.7               1.1        0.105  0.1   0.8            True
# 4           3.7               8.1        0.062 -1.1   0.6            True

# %% [markdown]
# # Drop target from features

# %%
X_train = train.drop(columns=['yrs', 'player'])
y_train = train['yrs']
X_val = val.drop(columns=['yrs', 'player'])
y_val = val['yrs']
X_test = test.drop(columns=['yrs', 'player'])
y_test = test['yrs']

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((828, 15), (828,), (478, 15), (478,), (966, 15), (966,))

# %% [markdown]
# # Get baseline linear regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X_val)

# %%
score = mean_absolute_error(y_val, y_pred)
score
# Out:
# 2.3253809688483194

# %%
y_pred = model.predict(X_test)

# %%
score_test = mean_absolute_error(y_test, y_pred)
score_test
# Out:
# 3.4739595166667057

# %% [markdown]
# # Using random forest regressor

# %%
model1 = RandomForestRegressor(n_estimators=1000, random_state=42)
model1.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
y_pred1 = model1.predict(X_val)
score1 = mean_absolute_error(y_val, y_pred1)
print('Validation score:', score1)
y_pred2 = model1.predict(X_test)
score2 = mean_absolute_error(y_test, y_pred2)
print('Test score:', score2)
# Out:
# Validation score: 1.5035857740585772
# Test score: 1.8228343685300208

# %% [markdown]
# # Pickle The Model

# %%
joblib.dump(model1, 'nba_model')
# Out:
# ['nba_model']

# %% [markdown]
# # Testing the API

# %%
url = 'https://nba-project.herokuapp.com/api'

# %%
data = json.dumps({'all_nba': 2, 'all_star': 9, 'draft_yr': 1976, 'pk': 8, 'fg_percentage': 0.537,
'tp_percentage': 0, 'ft_percentage': 0.721, 'minutes_per_game': 28.4, 
'points_per_game': 14.5, 'trb_per_game': 9.1, 'assists_per_game': 1.4,
'ws_per_game': 0.154, 'bpm': 1.6, 'vorp': 41.5, 'attend_college': 1})

# %%
print(data)
# Out:
# {"all_nba": 2, "all_star": 9, "draft_yr": 1976, "pk": 8, "fg_percentage": 0.537, "tp_percentage": 0, "ft_percentage": 0.721, "minutes_per_game": 28.4, "points_per_game": 14.5, "trb_per_game": 9.1, "assists_per_game": 1.4, "ws_per_game": 0.154, "bpm": 1.6, "vorp": 41.5, "attend_college": 1}

# %%
send = requests.post(url, data)

# %%
send.json()
# Out:
# {'results': {'y_pred': 18}}
